# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
jags_csvs = os.listdir('Jaguars_CSVs')
jags_dfs = [pd.read_csv('Jaguars_CSVs/'+csv) for csv in jags_csvs]
for df in jags_dfs:
    df['Date'] = pd.to_datetime(df['Date'])

# %%
def make_scatter_and_pie_figure(df,fig_name,save=False):
    fig, axes = plt.subplots(2, 1, figsize=(15, 10))
    sns.set_style('whitegrid')
    #scatter
    sns.scatterplot(ax=axes[0],x=df['Date'],y=df["Compound_Sentiment_Score"],hue=df['Positive_Sentiment'])
    axes[0].set_title('Positive and Negative Sentiment Socores over Time Scatter Plot',fontsize=12)
    #pie
    true = len(df.loc[(df['Positive_Sentiment']==True)])
    false = len(df.loc[(df['Positive_Sentiment']==False)])
    axes[1].pie([false,true],labels=["Negative",'Positive'])
    axes[1].set_title('Pie Plot of Sentiment Labels',fontsize=12)
    fig.suptitle(fig_name, fontsize=20)
    if save: #save the figure
        plt.savefig(fig_name)

# %%
jags_csvs
# Out:
# ['Jaguars_Game10_Chiefs.csv',
#  'Jaguars_Game11_Ravens.csv',
#  'Jaguars_Game1_Commanders.csv',
#  'Jaguars_Game2_Colts.csv',
#  'Jaguars_Game3_Chargers.csv',
#  'Jaguars_Game4_Eagles.csv',
#  'Jaguars_Game5_Texans.csv',
#  'Jaguars_Game6_Colts.csv',
#  'Jaguars_Game7_Giants.csv',
#  'Jaguars_Game8_Broncos.csv',
#  'Jaguars_Game9_Raiders.csv',
#  'Jaguars_Pre_Game1_Raiders.csv',
#  'Jaguars_Pre_Game2_Browns.csv',
#  'Jaguars_Pre_Game3_Steelers.csv']

# %%
make_scatter_and_pie_figure(jags_dfs[0], 'Jags_Charts/Jags_Chiefs', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[1], 'Jags_Charts/Jags_Ravens', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[2], 'Jags_Charts/Jags_Commanders', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[3], 'Jags_Charts/Jags_Colts', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[4], 'Jags_Charts/Jags_Chargers', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[5], 'Jags_Charts/Jags_Eagles', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[6], 'Jags_Charts/Jags_Texans', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[7], 'Jags_Charts/Jags_Colts_2', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[8], 'Jags_Charts/Jags_Giants', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[9], 'Jags_Charts/Jags_Broncos', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[10], 'Jags_Charts/Jags_Raiders_2', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[11], 'Jags_Charts/Jags_Raiders', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[12], 'Jags_Charts/Jags_Browns', save=True)

# %%
make_scatter_and_pie_figure(jags_dfs[13], 'Jags_Charts/Jags_Steelers', save=True)
