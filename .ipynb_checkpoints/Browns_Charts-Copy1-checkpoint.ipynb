# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# %%
browns_csvs = os.listdir('Browns_CSVs')
browns_dfs = [pd.read_csv('Browns_CSVs/'+csv) for csv in browns_csvs]
jags_csvs = os.listdir('Jaguars_CSVs')
jags_dfs = [pd.read_csv('Jaguars_CSVs/'+csv) for csv in jags_csvs]

# %%
browns_dfs[0].head() # 0 = Bears #
# Out:
#    Unnamed: 0                   ID                       Date            User  \
# 0           0  1594842799882797057  2022-11-21 23:58:48+00:00      viccarucci
# 1           2  1594842560756842496  2022-11-21 23:57:51+00:00      AlexPaugh_
# 2           3  1594842374055796743  2022-11-21 23:57:07+00:00  TheAngryBird63
# 3           4  1594842266069499905  2022-11-21 23:56:41+00:00    GOLFCRAZY216
# 4           5  1594842060087083008  2022-11-21 23:55:52+00:00      TheScoop27
#
#                                                Tweet  \
# 0  Please join us at 7:30p for Sports Talk Live B...
# 1  if cinderellas shoe fit perfectly, then why di...
# 2  3 winning seasons in 20 years is not “mediocri...
# 3  @MaryKayCabot The #Browns are not interested i...
# 4  @DiekenDisco Negative. I saw &amp; read every ...
#
#                                             HashTags  Likes  Retweets  \
# 0             ['Bills', 'Browns', 'Lions', 'Sabres']      2         1
# 1  ['ytshort', 'ytshorts', 'youtube', 'youtuber',...      3         0
# 2                                         ['Browns']      0         0
# 3                                         ['Browns']      0         0
# 4                                         ['Browns']      1         0
#
#                                         MentionUsers LocationCoordinates  \
# 0  [User(username='WGRZ', id=15308015, displaynam...                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3  [User(username='MaryKayCabot', id=35107066, di...                 NaN
# 4  [User(username='DiekenDisco', id=1437219864196...                 NaN
#
#                                          clean_Tweet  NLTK_Sentiment_Analysis  \
# 0  please join us 7 30p sports talk live buffalo ...                   0.7506
# 1  cinderellas shoe fit perfectly fall sporadic t...                   0.7717
# 2  3 winning seasons 20 years mediocrity chico fl...                   0.0516
# 3  interested getting better could give bleep tak...                   0.8442
# 4  negative saw amp read every lot ride season am...                  -0.5719
#
#    TextBlob_Sentiment_Analysis  Compound_Sentiment_Score  Positive_Sentiment
# 0                    -0.131818                  0.618782                True
# 1                     0.700000                  1.471700                True
# 2                     0.091667                  0.143267                True
# 3                     0.087500                  0.931700                True
# 4                    -0.300000                 -0.871900               False

# %%
jags_dfs[0].head() # 0 = Broncos #
# Out:
#    Unnamed: 0                   ID                       Date  \
# 0           0  1592304141795459072  2022-11-14 23:51:05+00:00
# 1           2  1592302327896997890  2022-11-14 23:43:53+00:00
# 2           3  1592301422049169408  2022-11-14 23:40:17+00:00
# 3           5  1592288660862689281  2022-11-14 22:49:34+00:00
# 4           7  1592285210053599233  2022-11-14 22:35:51+00:00
#
#               User                                              Tweet  \
# 0      MaqagiWonga  If it pleases the court, your honor ... The de...
# 1  englishheadline  ‘How is that not a penalty?’ Twitter reacts to...
# 2         MoeMoton  Yeah the #Chiefs are tough to bottle up and st...
# 3   MonicaNunez___  summary (Eng/Spa) to follow. research especial...
# 4       dfilaroski  For those who may have missed it, not only did...
#
#                                             HashTags  Likes  Retweets  \
# 0  ['MondayThoughts', 'NewMusicMonday', 'JAX', 'J...      0         0
# 1  ['penalty', 'Twitter', 'reacts', 'Jaguars', 'b...      0         0
# 2                 ['Chiefs', 'Cardinals', 'Jaguars']     86         5
# 3                                        ['jaguars']      1         0
# 4                                        ['Jaguars']     19         0
#
#   MentionUsers LocationCoordinates  \
# 0          NaN                 NaN
# 1          NaN                 NaN
# 2          NaN                 NaN
# 3          NaN                 NaN
# 4          NaN                 NaN
#
#                                          clean_Tweet  NLTK_Sentiment_Analysis  \
# 0  pleases court honor defense calls stand pleasu...                   0.8779
# 1  penalty twitter reacts jaguars big hit juju sm...                  -0.4588
# 2  yeah tough bottle stifle get credit close loss...                  -0.1531
# 3  summary eng spa follow research especially rel...                  -0.5574
# 4  may missed cisco lay legal lick juju picked fu...                  -0.1779
#
#    TextBlob_Sentiment_Analysis  Compound_Sentiment_Score  Positive_Sentiment
# 0                     0.000000                  0.877900                True
# 1                     0.000000                 -0.458800               False
# 2                    -0.388889                 -0.541989               False
# 3                     0.233333                 -0.324067               False
# 4                     0.200000                  0.022100                True

# %%
b_game_1 = browns_dfs[0]

# %%
def remove_users_from_df(df, list_users):
    indxs = df[df['User'].isin(list_users)].index
    dfc = df.drop(indxs, inplace=False)
    return dfc

users = b_game_1.groupby(['User']).size().sort_values(ascending=False).head(5)
print(users)
l = list(users.index.values) 
b_game_1_c = remove_users_from_df(b_game_1,l)
b_game_1_c.groupby(['User']).size().sort_values(ascending=False).head(5)
# Out:
# User
# BrownsChat        169
# ScottPetrak        77
# ceasterlingABJ     72
# Iwashazed03        44
# RuiterWrongFAN     38
# dtype: int64
# User
# bsakes             37
# ArmyGunner1122     35
# MylesOffTheEdge    33
# Tom_RedRight88     32
# land_browns        31
# dtype: int64

# %%
browns_dfs[0].columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Date', 'User', 'Tweet', 'HashTags', 'Likes',
#        'Retweets', 'MentionUsers', 'LocationCoordinates', 'clean_Tweet',
#        'NLTK_Sentiment_Analysis', 'TextBlob_Sentiment_Analysis',
#        'Compound_Sentiment_Score', 'Positive_Sentiment'],
#       dtype='object')

# %%
def make_scatter_and_pie_figure(df,fig_name,save=False):
    fig, axes = plt.subplots(2, 1, figsize=(15, 10))
    sns.set_style('whitegrid')
    #scatter
    sns.scatterplot(ax=axes[0],x=df['Date'],y=df["Compound_Sentiment_Score"],hue=df['Positive_Sentiment'])
    axes[0].set_title('Positive and Negative Sentiment Socores over Time Scatter Plot',fontsize=12)
    #pie
    true = len(df.loc[(df['Positive_Sentiment']==True)])
    false = len(df.loc[(df['Positive_Sentiment']==False)])
    axes[1].pie([false,true],labels=["Negative",'Positive'])
    axes[1].set_title('Pie Plot of Sentiment Labels',fontsize=12)
    fig.suptitle(fig_name, fontsize=20)
    if save: #save the figure
        plt.savefig(fig_name)

# %%
browns_csvs
# Out:
# ['Browns_Game10_Bills.csv',
#  'Browns_Game11_Buccaneers.csv',
#  'Browns_Game1_Panthers.csv',
#  'Browns_Game2_Jets.csv',
#  'Browns_Game3_Steelers.csv',
#  'Browns_Game4_Falcons.csv',
#  'Browns_Game5_Chargers.csv',
#  'Browns_Game6_Patriots.csv',
#  'Browns_Game7_Ravens.csv',
#  'Browns_Game8_Bengals.csv',
#  'Browns_Game9_Dolphins.csv',
#  'Browns_Pre_Game1_Jaguars.csv',
#  'Browns_Pre_Game2_Eagles.csv',
#  'Browns_Pre_Game3_Bears.csv']

# %%
make_scatter_and_pie_figure(browns_dfs[0], 'Browns vs. Bills')

# %%
# users = browns_dfs[0].groupby(['User']).size().sort_values(ascending=False).head(5)
# l = list(users.index.values) 
# make_scatter_and_pie_figure(remove_users_from_df(browns_dfs[0], l), 'Browns vs. Bears - Removed Users')

# %%
make_scatter_and_pie_figure(browns_dfs[1], 'Browns vs. Buccaneers')

# %%
make_scatter_and_pie_figure(browns_dfs[2], 'Browns vs. Panthers')

# %%
make_scatter_and_pie_figure(browns_dfs[3], 'Browns vs. Jets')

# %%
make_scatter_and_pie_figure(browns_dfs[4], 'Browns vs. Steelers')

# %%
make_scatter_and_pie_figure(browns_dfs[5], 'Browns vs. Falcons')

# %%
make_scatter_and_pie_figure(browns_dfs[6], 'Browns vs. Chargers')

# %%
make_scatter_and_pie_figure(browns_dfs[7], 'Browns vs. Patriots')

# %%
make_scatter_and_pie_figure(browns_dfs[8], 'Browns vs. Ravens')

# %%
make_scatter_and_pie_figure(browns_dfs[9], 'Browns vs. Bengals')

# %%
make_scatter_and_pie_figure(browns_dfs[10], 'Browns vs. Dolphins')

# %%
make_scatter_and_pie_figure(browns_dfs[11], 'Browns vs. Jaguars')

# %%
make_scatter_and_pie_figure(browns_dfs[12], 'Browns vs. Eagles')

# %%
make_scatter_and_pie_figure(browns_dfs[13], 'Browns vs. Bears')

# %%
chubb_df3 = browns_dfs[3].loc[browns_dfs[3]['clean_Tweet'].str.contains('chubb')]
make_scatter_and_pie_figure(chubb_df3, 'Browns vs. Jets - Chubb')

# %%
coach_df2 = browns_dfs[3].loc[browns_dfs[3]['clean_Tweet'].str.contains('defense')]
make_scatter_and_pie_figure(coach_df2, 'Browns vs. Jets - defense')
