# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
import re

# %%
from Collect_and_Clean_Tweets import scrap

# %%
query = 'Cheifs (#Cheifs AND -#Jaguars AND -#DUUUVAL) until:2022-11-15 since:2022-11-13'
limit = 500 #not really limited just take a long time
df = pd.DataFrame() 
df = scrap(query,limit)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   7 non-null      int64
#  1   Date                 7 non-null      datetime64[ns, UTC]
#  2   User                 7 non-null      object
#  3   Tweet                7 non-null      object
#  4   HashTags             7 non-null      object
#  5   Likes                7 non-null      int64
#  6   Retweets             7 non-null      int64
#  7   MentionUsers         2 non-null      object
#  8   LocationCoordinates  0 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(3), object(5)
# memory usage: 632.0+ bytes

# %%
from Collect_and_Clean_Tweets import clean_tweet_feature

# %%
df = clean_tweet_feature(df)

# %%
df.head()
# Out:
#                     ID                      Date            User  \
# 0  1592165700201758721 2022-11-14 14:40:58+00:00  CharlesVoiceVO
# 1  1591943981017231361 2022-11-13 23:59:56+00:00        nojumper
# 2  1591916590416932864 2022-11-13 22:11:06+00:00        Beezy85T
# 3  1591913854396960769 2022-11-13 22:00:13+00:00        akaemii_
# 4  1591880731189735424 2022-11-13 19:48:36+00:00  HumphriesDarla
#
#                                                Tweet  \
# 0  @SaundersSzn99 @CheifsKingdom_ Yo you bring th...
# 1  #JuJuSmithSchuster took a nasty hit during the...
# 2  Wonder what the hot take gonna be tomorrow now...
# 3  HEY BUFFALO 🐃 ! WHAT HAPPENED???? AND KANSAS C...
# 4  @PatrickMahomes #cheifs kingdom all of you tha...
#
#                                             HashTags  Likes  Retweets  \
# 0         [beastmode, pumped, cheifskingdom, cheifs]      0         0
# 1                        [JuJuSmithSchuster, Cheifs]    318        25
# 2                       [Cheifs, AFC, ChiefsKingdom]      0         0
# 3  [cheifs, billslost, BillsMafia, KansasCityChie...      1         0
# 4                                           [cheifs]      0         0
#
#                                         MentionUsers LocationCoordinates  \
# 0  [https://twitter.com/SaundersSzn99, https://tw...                None
# 1                                               None                None
# 2                                               None                None
# 3                                               None                None
# 4               [https://twitter.com/PatrickMahomes]                None
#
#                                          clean_Tweet
# 0  yo you bring that energy that smack love watch...
# 1                 took nasty hit during jaguars game
# 2  wonder what hot take gonna be tomorrow now tha...
# 3  hey buffalo what happened kansas city is first...
# 4  kingdom all you that helped me get through my ...

# %%
from Collect_and_Clean_Tweets import create_col_of_Sentiment_Analysis

# %%
df = create_col_of_Sentiment_Analysis(df)

# %%
df.head()
# Out:
#                     ID                      Date            User  \
# 0  1592165700201758721 2022-11-14 14:40:58+00:00  CharlesVoiceVO
# 1  1591943981017231361 2022-11-13 23:59:56+00:00        nojumper
# 2  1591916590416932864 2022-11-13 22:11:06+00:00        Beezy85T
# 3  1591913854396960769 2022-11-13 22:00:13+00:00        akaemii_
# 4  1591880731189735424 2022-11-13 19:48:36+00:00  HumphriesDarla
#
#                                                Tweet  \
# 0  @SaundersSzn99 @CheifsKingdom_ Yo you bring th...
# 1  #JuJuSmithSchuster took a nasty hit during the...
# 2  Wonder what the hot take gonna be tomorrow now...
# 3  HEY BUFFALO 🐃 ! WHAT HAPPENED???? AND KANSAS C...
# 4  @PatrickMahomes #cheifs kingdom all of you tha...
#
#                                             HashTags  Likes  Retweets  \
# 0         [beastmode, pumped, cheifskingdom, cheifs]      0         0
# 1                        [JuJuSmithSchuster, Cheifs]    318        25
# 2                       [Cheifs, AFC, ChiefsKingdom]      0         0
# 3  [cheifs, billslost, BillsMafia, KansasCityChie...      1         0
# 4                                           [cheifs]      0         0
#
#                                         MentionUsers LocationCoordinates  \
# 0  [https://twitter.com/SaundersSzn99, https://tw...                None
# 1                                               None                None
# 2                                               None                None
# 3                                               None                None
# 4               [https://twitter.com/PatrickMahomes]                None
#
#                                          clean_Tweet  \
# 0  yo you bring that energy that smack love watch...
# 1                 took nasty hit during jaguars game
# 2  wonder what hot take gonna be tomorrow now tha...
# 3  hey buffalo what happened kansas city is first...
# 4  kingdom all you that helped me get through my ...
#
#                                   Sentiment_Analysis
# 0  {'neg': 0.057, 'neu': 0.707, 'pos': 0.236, 'co...
# 1  {'neg': 0.419, 'neu': 0.581, 'pos': 0.0, 'comp...
# 2  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.245, 'neu': 0.755, 'pos': 0.0, 'comp...

# %%
from Collect_and_Clean_Tweets import create_col_of_labels_for_tweet_sentiment

# %%
df = create_col_of_labels_for_tweet_sentiment(df)

# %%
df.head()
# Out:
#                     ID                      Date            User  \
# 0  1592165700201758721 2022-11-14 14:40:58+00:00  CharlesVoiceVO
# 1  1591943981017231361 2022-11-13 23:59:56+00:00        nojumper
# 2  1591916590416932864 2022-11-13 22:11:06+00:00        Beezy85T
# 3  1591913854396960769 2022-11-13 22:00:13+00:00        akaemii_
# 4  1591880731189735424 2022-11-13 19:48:36+00:00  HumphriesDarla
#
#                                                Tweet  \
# 0  @SaundersSzn99 @CheifsKingdom_ Yo you bring th...
# 1  #JuJuSmithSchuster took a nasty hit during the...
# 2  Wonder what the hot take gonna be tomorrow now...
# 3  HEY BUFFALO 🐃 ! WHAT HAPPENED???? AND KANSAS C...
# 4  @PatrickMahomes #cheifs kingdom all of you tha...
#
#                                             HashTags  Likes  Retweets  \
# 0         [beastmode, pumped, cheifskingdom, cheifs]      0         0
# 1                        [JuJuSmithSchuster, Cheifs]    318        25
# 2                       [Cheifs, AFC, ChiefsKingdom]      0         0
# 3  [cheifs, billslost, BillsMafia, KansasCityChie...      1         0
# 4                                           [cheifs]      0         0
#
#                                         MentionUsers LocationCoordinates  \
# 0  [https://twitter.com/SaundersSzn99, https://tw...                None
# 1                                               None                None
# 2                                               None                None
# 3                                               None                None
# 4               [https://twitter.com/PatrickMahomes]                None
#
#                                          clean_Tweet  \
# 0  yo you bring that energy that smack love watch...
# 1                 took nasty hit during jaguars game
# 2  wonder what hot take gonna be tomorrow now tha...
# 3  hey buffalo what happened kansas city is first...
# 4  kingdom all you that helped me get through my ...
#
#                                   Sentiment_Analysis  Positive_Sentiment
# 0  {'neg': 0.057, 'neu': 0.707, 'pos': 0.236, 'co...                True
# 1  {'neg': 0.419, 'neu': 0.581, 'pos': 0.0, 'comp...               False
# 2  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...               False
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...               False
# 4  {'neg': 0.245, 'neu': 0.755, 'pos': 0.0, 'comp...               False

# %%
from Collect_and_Clean_Tweets import create_col_of_compound_tweet_sentiment_score

# %%
df = create_col_of_compound_tweet_sentiment_score(df)

# %%
df.head()
# Out:
#                     ID                      Date            User  \
# 0  1592165700201758721 2022-11-14 14:40:58+00:00  CharlesVoiceVO
# 1  1591943981017231361 2022-11-13 23:59:56+00:00        nojumper
# 2  1591916590416932864 2022-11-13 22:11:06+00:00        Beezy85T
# 3  1591913854396960769 2022-11-13 22:00:13+00:00        akaemii_
# 4  1591880731189735424 2022-11-13 19:48:36+00:00  HumphriesDarla
#
#                                                Tweet  \
# 0  @SaundersSzn99 @CheifsKingdom_ Yo you bring th...
# 1  #JuJuSmithSchuster took a nasty hit during the...
# 2  Wonder what the hot take gonna be tomorrow now...
# 3  HEY BUFFALO 🐃 ! WHAT HAPPENED???? AND KANSAS C...
# 4  @PatrickMahomes #cheifs kingdom all of you tha...
#
#                                             HashTags  Likes  Retweets  \
# 0         [beastmode, pumped, cheifskingdom, cheifs]      0         0
# 1                        [JuJuSmithSchuster, Cheifs]    318        25
# 2                       [Cheifs, AFC, ChiefsKingdom]      0         0
# 3  [cheifs, billslost, BillsMafia, KansasCityChie...      1         0
# 4                                           [cheifs]      0         0
#
#                                         MentionUsers LocationCoordinates  \
# 0  [https://twitter.com/SaundersSzn99, https://tw...                None
# 1                                               None                None
# 2                                               None                None
# 3                                               None                None
# 4               [https://twitter.com/PatrickMahomes]                None
#
#                                          clean_Tweet  \
# 0  yo you bring that energy that smack love watch...
# 1                 took nasty hit during jaguars game
# 2  wonder what hot take gonna be tomorrow now tha...
# 3  hey buffalo what happened kansas city is first...
# 4  kingdom all you that helped me get through my ...
#
#                                   Sentiment_Analysis  Positive_Sentiment  \
# 0  {'neg': 0.057, 'neu': 0.707, 'pos': 0.236, 'co...                True
# 1  {'neg': 0.419, 'neu': 0.581, 'pos': 0.0, 'comp...               False
# 2  {'neg': 0.091, 'neu': 0.909, 'pos': 0.0, 'comp...               False
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...               False
# 4  {'neg': 0.245, 'neu': 0.755, 'pos': 0.0, 'comp...               False
#
#    Compound_Sentiment Score
# 0                    0.7650
# 1                   -0.5574
# 2                   -0.2960
# 3                    0.0000
# 4                   -0.5994

# %%
from Collect_and_Clean_Tweets import make_csv_from_df

# %%
make_csv_from_df(df,'Cheifs.csv')
