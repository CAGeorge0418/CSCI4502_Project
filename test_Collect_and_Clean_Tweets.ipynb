# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
import re

# %%
from Collect_and_Clean_Tweets import scrap

# %%
query = 'Broncos (#Broncos AND -#DUUUVAL AND -#Jags) until:2022-10-31 since:2022'
limit = 10 #not really limited just take a long time
df = pd.DataFrame() 
df = scrap(query,limit)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10 non-null     int64
#  1   Date                 10 non-null     datetime64[ns, UTC]
#  2   User                 10 non-null     object
#  3   Tweet                10 non-null     object
#  4   HashTags             10 non-null     object
#  5   Likes                10 non-null     int64
#  6   Retweets             10 non-null     int64
#  7   MentionUsers         1 non-null      object
#  8   LocationCoordinates  0 non-null      object
# dtypes: datetime64[ns, UTC](1), int64(3), object(5)
# memory usage: 848.0+ bytes

# %%
from Collect_and_Clean_Tweets import clean_tweet_feature

# %%
df = clean_tweet_feature(df)

# %%
df.head()
# Out:
#                     ID                      Date            User  \
# 0  1586870174208200705 2022-10-30 23:58:26+00:00          kfzoid
# 1  1586870072387174402 2022-10-30 23:58:02+00:00   AiceFerraganz
# 2  1586869811207753728 2022-10-30 23:57:00+00:00  Michel33074368
# 3  1586869560447213569 2022-10-30 23:56:00+00:00    BroncosViews
# 4  1586869360991342592 2022-10-30 23:55:12+00:00      MileHighNB
#
#                                                Tweet  \
# 0  #NFL #weekeight #backtwoback #wins #twentytwen...
# 1  Which is more embarrassing to admit? #furry #B...
# 2  Looking for outstanding quality shipping conta...
# 3  Travis Etienne's career game soured by late IN...
# 4  Looking at remainder of #Broncos schedule, and...
#
#                                             HashTags  Likes  Retweets  \
# 0  [NFL, weekeight, backtwoback, wins, twentytwen...      0         0
# 1  [furry, BroncosCountry, football, memes, bronc...      0         0
# ...

# %%
from Collect_and_Clean_Tweets import create_col_of_Sentiment_Analysis

# %%
df = create_col_of_Sentiment_Analysis(df)

# %%
df.head()
# Out:
#                     ID                      Date            User  \
# 0  1586870174208200705 2022-10-30 23:58:26+00:00          kfzoid
# 1  1586870072387174402 2022-10-30 23:58:02+00:00   AiceFerraganz
# 2  1586869811207753728 2022-10-30 23:57:00+00:00  Michel33074368
# 3  1586869560447213569 2022-10-30 23:56:00+00:00    BroncosViews
# 4  1586869360991342592 2022-10-30 23:55:12+00:00      MileHighNB
#
#                                                Tweet  \
# 0  #NFL #weekeight #backtwoback #wins #twentytwen...
# 1  Which is more embarrassing to admit? #furry #B...
# 2  Looking for outstanding quality shipping conta...
# 3  Travis Etienne's career game soured by late IN...
# 4  Looking at remainder of #Broncos schedule, and...
#
#                                             HashTags  Likes  Retweets  \
# 0  [NFL, weekeight, backtwoback, wins, twentytwen...      0         0
# 1  [furry, BroncosCountry, football, memes, bronc...      0         0
# ...

# %%
from Collect_and_Clean_Tweets import create_col_of_labels_for_tweet_sentiment

# %%
df = create_col_of_labels_for_tweet_sentiment(df)

# %%
df.head()
# Out:
#                     ID                      Date            User  \
# 0  1586870174208200705 2022-10-30 23:58:26+00:00          kfzoid
# 1  1586870072387174402 2022-10-30 23:58:02+00:00   AiceFerraganz
# 2  1586869811207753728 2022-10-30 23:57:00+00:00  Michel33074368
# 3  1586869560447213569 2022-10-30 23:56:00+00:00    BroncosViews
# 4  1586869360991342592 2022-10-30 23:55:12+00:00      MileHighNB
#
#                                                Tweet  \
# 0  #NFL #weekeight #backtwoback #wins #twentytwen...
# 1  Which is more embarrassing to admit? #furry #B...
# 2  Looking for outstanding quality shipping conta...
# 3  Travis Etienne's career game soured by late IN...
# 4  Looking at remainder of #Broncos schedule, and...
#
#                                             HashTags  Likes  Retweets  \
# 0  [NFL, weekeight, backtwoback, wins, twentytwen...      0         0
# 1  [furry, BroncosCountry, football, memes, bronc...      0         0
# ...

# %%
from Collect_and_Clean_Tweets import create_col_of_compound_tweet_sentiment_score

# %%
df = create_col_of_compound_tweet_sentiment_score(df)

# %%
df.head()
# Out:
#                     ID                      Date            User  \
# 0  1586870174208200705 2022-10-30 23:58:26+00:00          kfzoid
# 1  1586870072387174402 2022-10-30 23:58:02+00:00   AiceFerraganz
# 2  1586869811207753728 2022-10-30 23:57:00+00:00  Michel33074368
# 3  1586869560447213569 2022-10-30 23:56:00+00:00    BroncosViews
# 4  1586869360991342592 2022-10-30 23:55:12+00:00      MileHighNB
#
#                                                Tweet  \
# 0  #NFL #weekeight #backtwoback #wins #twentytwen...
# 1  Which is more embarrassing to admit? #furry #B...
# 2  Looking for outstanding quality shipping conta...
# 3  Travis Etienne's career game soured by late IN...
# 4  Looking at remainder of #Broncos schedule, and...
#
#                                             HashTags  Likes  Retweets  \
# 0  [NFL, weekeight, backtwoback, wins, twentytwen...      0         0
# 1  [furry, BroncosCountry, football, memes, bronc...      0         0
# ...

# %%
from Collect_and_Clean_Tweets import make_csv_from_df

# %%
make_csv_from_df(df,'test_tweets.csv')
