# %%
import http.client
import json

conn = http.client.HTTPSConnection("twitter154.p.rapidapi.com")

headers = {
    'X-RapidAPI-Key': "ca6bb955c2msh38c3f732e0493bbp13ab54jsnd096309f139d",
    'X-RapidAPI-Host': "twitter154.p.rapidapi.com"
    }

conn.request("GET", "/search/search?query=%23broncos&section=top&min_retweets=20&min_likes=20&limit=15&start_date=2022-09-20&end_date=2022-09-27&language=en", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"results":[{"tweet_id":"1574395398772338690","creation_date":"Mon Sep 26 13:48:08 +0000 2022","text":"The #49ers went to the NFC Championship last year. \n\nDon’t underestimate what the #Broncos did last night.","media_url":null,"video_url":null,"user":{"creation_date":"Mon Jan 02 04:02:08 +0000 2017","user_id":"815770124036644864","username":"DailyBroncos","name":"Denver Broncos 365","follower_count":11727,"following_count":208,"favourites_count":16719,"is_private":false,"is_verified":false,"location":"","profile_pic_url":"https://pbs.twimg.com/profile_images/1241213527832043521/XfRGOrde_normal.jpg","profile_banner_url":"https://pbs.twimg.com/profile_banners/815770124036644864/1639244451","description":"Not always the news you want to hear, but need to hear. Breaking down the Broncos like no other, year-round.","external_url":null,"number_of_tweets":8724,"bot":false,"timestamp":1483329728,"has_nft_avatar":false},"language":"en","favorite_count":1013,"retweet_count":48,"reply_count"
# ...
